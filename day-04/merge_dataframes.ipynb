# %%
import pandas as pd

transactions_df = pd.read_csv("data/transactions.csv")
customers_df = pd.read_csv("data/customers.csv")

# %%
# Merge 

new_table = transactions_df.merge(
    customers_df,
    on="customer_id",
    how="left"
)

print(new_table)
# Out:
#   transaction_id customer_id transaction_type    amount      status  \
# 0          TX001        C001             Data    5000.0  successful
# 1          TX002        C002          Airtime    2000.0      failed
# 2          TX003        C001      Electricity   15000.0  successful
# 3          TX004        C003    Fund Transfer  100000.0  successful
# 4          TX005        C002             Data       NaN      failed
# 5          TX006        C004    Fund Transfer  250000.0  successful
# 6          TX007        C001          Airtime    3000.0  successful
# 7          TX008        C005      Electricity   45000.0     pending
# 8          TX009        C003    Fund Transfer  100000.0  successful
# 9          TX009        C003    Fund Transfer  100000.0  successful
#
#          date  failed_attempts  age location  account_age_days
# 0  2026-08-01                0   34    Abuja               900
# 1  2026-08-01                2   29    Lagos               400
# ...
