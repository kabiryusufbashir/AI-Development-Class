# %%
import pandas as pd

df = pd.read_csv("data/transactions.csv")

result = (
    df.groupby("transaction_type")["amount"].sum()
)

print(result)
# Out:
# transaction_type
# Airtime            5000.0
# Data               5000.0
# Electricity       60000.0
# Fund Transfer    550000.0
# Name: amount, dtype: float64

# %%
summary = (
    df.groupby("transaction_type")["amount"].agg(["count", "sum", "mean", "max"])
)

print(summary)
# Out:
#                   count       sum      mean       max
# transaction_type
# Airtime               2    5000.0    2500.0    3000.0
# Data                  1    5000.0    5000.0    5000.0
# Electricity           2   60000.0   30000.0   45000.0
# Fund Transfer         4  550000.0  137500.0  250000.0
